# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt

# %%
threshVal = np.loadtxt("txt_files_py/threshVal00001_cells.txt")
threshVal2 = np.loadtxt("txt_files_py/threshVal000005_cells2.txt") #threshVal0001_2
threshVal[:,0] = np.linspace(3.66, 38.84, threshVal[:,0].shape[0])
threshVal2[:,0] = np.linspace(3.66, 38.84, threshVal2[:,0].shape[0])

# %%
plt.plot(threshVal[:,0], threshVal[:,1], alpha=0.6, label='1')
plt.plot(threshVal2[:,0], threshVal2[:,1], alpha=0.6, label='2')
plt.legend()
