# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load files

# %%
M1 = np.loadtxt("probCleanNico30deg.txt") #probCleanNico30deg
M2 = np.loadtxt("probCleanStandard3.txt") #probCleanStandard3
print('M1 shape:', M1.shape)
print('M2 shape:', M2.shape)
if(M2.shape[0] > M1.shape[0]):
    M2 = M2[:M1.shape[0],:]
else:
    M1 = M1[:M2.shape[0],:]
# Out:
# M1 shape: (539, 31)
# M2 shape: (538, 31)

# %% [markdown]
# ## Compute p mean
#
# #### Nicolas

# %%
M1_p = M1[:,1:]
middle1 = int(M1_p.shape[1]/2)
M1_p_mean = np.nanmean(M1_p,axis=1)
p1 = np.mean(M1_p_mean)
print('p =',p1)

M1_p_r = M1[:,1:middle1+1]
M1_p_mean_r = np.nanmean(M1_p_r,axis=1)
p1_r = np.mean(M1_p_mean_r)
print('p_right =',p1_r)

M1_p_l = M1[:,middle1:]
M1_p_mean_l = np.nanmean(M1_p_l,axis=1)
p1_l = np.mean(M1_p_mean_l)
print('p_left =',p1_l)
# Out:
# p = 0.7173257595838011
# p_right = 0.632348758316109
# p_left = 0.7829928244911943

# %% [markdown]
# #### Standard

# %%
M2_p = M2[:,1:]
middle2 = int(M2_p.shape[1]/2)
M2_p_mean = np.nanmean(M2_p,axis=1)
p2 = np.mean(M2_p_mean)
print('p =',p2)

M2_p_r = M2[:,1:middle2+1]
M2_p_mean_r = np.nanmean(M2_p_r,axis=1)
p2_r = np.mean(M2_p_mean_r)
print('p_right =',p2_r)

M2_p_l = M2[:,middle2:]
M2_p_mean_l = np.nanmean(M2_p_l,axis=1)
p2_l = np.mean(M2_p_mean_l)
print('p_left =',p2_l)
# Out:
# p = 0.6928216487961436
# p_right = 0.5896414325537794
# p_left = 0.7738947701447336

# %% [markdown]
# #### Mean for each beam for both cases

# %%
X = np.arange(M1_p.shape[1])
plt.plot(X, np.nanmean(M1_p,axis=0), label='Nicolas')
plt.plot(X, np.nanmean(M2_p,axis=0), label='Standard')

plt.legend()

# %%
plt.plot(X, np.nanmedian(M1_p,axis=0), label='Nicolas')
plt.plot(X, np.nanmedian(M2_p,axis=0), label='Standard')

plt.legend()

# %%
def draw_plot(data, offset,edge_color, fill_color):
    pos = np.arange(data.shape[1])+offset 
    # Filter data using np.isnan
    mask = ~np.isnan(data)
    filtered_data = [d[m] for d, m in zip(data.T, mask.T)]
    bp = ax.boxplot(filtered_data, positions= pos, widths=0.3, patch_artist=True, manage_xticks=False)
    for element in ['boxes', 'whiskers', 'fliers', 'medians', 'caps']:
        plt.setp(bp[element], color=edge_color)
    for patch in bp['boxes']:
        patch.set(facecolor=fill_color)

fig, ax = plt.subplots()
draw_plot(M1_p, -0.2, "blue", "white")
draw_plot(M2_p, +0.2,"red", "white")
plt.xticks(xrange(10))
plt.show()

# %% [markdown]
# ## Plot distribution
#
# #### Nicolas

# %%
M1_flat = M1[:,1:].flatten()
M1_flat = M1_flat[~np.isnan(M1_flat)]
weights = np.ones_like(M1_flat)/float(len(M1_flat))
plt.hist(M1_flat, weights=weights)
# Out:
# (array([0.13168826, 0.01915804, 0.02108004, 0.01990204, 0.01946804,
#         0.03050406, 0.04054808, 0.0517701 , 0.18891438, 0.47696695]),
#  array([8.33333000e-04, 1.00708600e-01, 2.00583866e-01, 3.00459133e-01,
#         4.00334400e-01, 5.00209666e-01, 6.00084933e-01, 6.99960200e-01,
#         7.99835467e-01, 8.99710733e-01, 9.99586000e-01]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Standard

# %%
M2_flat = M2[:,1:].flatten()
M2_flat = M2_flat[~np.isnan(M2_flat)]
weights = np.ones_like(M2_flat)/float(len(M2_flat))
plt.hist(M2_flat, weights=weights)
# Out:
# (array([0.17158443, 0.01438135, 0.01816266, 0.01270766, 0.016303  ,
#         0.02516737, 0.0358914 , 0.0358914 , 0.09521448, 0.57469626]),
#  array([8.33333000e-04, 9.67201997e-02, 1.92607066e-01, 2.88493933e-01,
#         3.84380800e-01, 4.80267667e-01, 5.76154533e-01, 6.72041400e-01,
#         7.67928267e-01, 8.63815133e-01, 9.59702000e-01]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## During time
#
# #### Nicolas

# %% [markdown]
# #### Standard

# %%
plt.plot(M1[:,0],M1_p_mean_r, label='nico', alpha=0.5)
plt.plot(M2[:,0],M2_p_mean_r, label='standard', alpha=0.5)
plt.legend()

# %%
fig, ax = plt.subplots(1,3,sharex=True,sharey=True, figsize=(15,3))
ax[0].plot(M1[:,0],M1_p[:,0], label='nico', alpha=0.5)
ax[0].plot(M2[:,0],M2_p[:,0], label='standard', alpha=0.5)
ax[1].plot(M1[:,0],M1_p[:,1], label='nico', alpha=0.5)
ax[1].plot(M2[:,0],M2_p[:,1], label='standard', alpha=0.5)
ax[2].plot(M1[:,0],M1_p[:,2], label='nico', alpha=0.5)
ax[2].plot(M2[:,0],M2_p[:,2], label='standard', alpha=0.5)

# %%
fig, ax = plt.subplots(1,3,sharex=True,sharey=True, figsize=(15,3))
ax[0].plot(M1[:,0],M1_p[:,3], label='nico', alpha=0.5)
ax[0].plot(M2[:,0],M2_p[:,3], label='standard', alpha=0.5)
ax[1].plot(M1[:,0],M1_p[:,4], label='nico', alpha=0.5)
ax[1].plot(M2[:,0],M2_p[:,4], label='standard', alpha=0.5)
ax[2].plot(M1[:,0],M1_p[:,5], label='nico', alpha=0.5)
ax[2].plot(M2[:,0],M2_p[:,5], label='standard', alpha=0.5)

# %%
plt.plot(M1[:,0],M1_p[:,3], label='nico', alpha=0.5)
plt.plot(M2[:,0],M2_p[:,3], label='standard', alpha=0.5)
plt.legend()

# %%
plt.plot(M1[:,0],M1_p[:,4], label='nico', alpha=0.5)
plt.plot(M2[:,0],M2_p[:,4], label='standard', alpha=0.5)
plt.legend()

# %%
plt.plot(M1[:,0],M1_p[:,5], label='nico', alpha=0.5)
plt.plot(M2[:,0],M2_p[:,5], label='standard', alpha=0.5)
plt.legend()
